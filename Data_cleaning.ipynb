# %%
import pandas as pd
df=pd.read_excel('factbook.xlsx')
df.head()
# Out:
#        Country Area(sq km) Birth rate(births/1000 population)  \
# 0       String      double                             double
# 1  Afghanistan      647500                              47.02
# 2     Akrotiri         123                                NaN
# 3      Albania       28748                              15.08
# 4      Algeria     2381740                              17.13
#
#   Current account balance Death rate(deaths/1000 population) Debt - external  \
# 0                  double                             double          double
# 1                     NaN                              20.75      8000000000
# 2                     NaN                                NaN             NaN
# 3              -504000000                               5.12      1410000000
# 4             11900000000                                4.6     21900000000
#
#   Electricity - consumption(kWh) Electricity - production(kWh)      Exports  \
# ...

# %%
import pandas as pd
df=pd.read_excel('factbook.xlsx')
missing_data_df=df.fillna(0)
new_df=missing_data_df.drop(labels=[0], axis=0) # axis=0 represent the first row, axis=1 represent first column
new_df
# Out:
#                          Country Area(sq km)  \
# 1                    Afghanistan      647500
# 2                       Akrotiri         123
# 3                        Albania       28748
# 4                        Algeria     2381740
# 5                 American Samoa         199
# 6                        Andorra         468
# 7                         Angola     1246700
# 8                       Anguilla         102
# 9                     Antarctica    14000000
# 10           Antigua and Barbuda         443
# 11                     Argentina     2766890
# 12                       Armenia       29800
# 13                         Aruba         193
# 14   Ashmore and Cartier Islands           5
# 15                     Australia     7686850
# 16                       Austria       83870
# 17                    Azerbaijan       86600
# 18                   Bahamas The       13940
# 19                       Bahrain         665
# 20                  Baker Island           1
# ...

# %%
import pandas as pd
df=pd.read_excel('factbook.xlsx')
missing_data_df=df.fillna(0)
missing_data_df.describe()
# Out:
#                 Country  Area(sq km)  Birth rate(births/1000 population)  \
# count               264          264                                 264
# unique              264          253                                 220
# top     Solomon Islands            5                                   0
# freq                  1            5                                  38
#
#         Current account balance  Death rate(deaths/1000 population)  \
# count                       264                                 264
# unique                      151                                 212
# top                           0                                   0
# freq                        114                                  38
#
#         Debt - external  Electricity - consumption(kWh)  \
# count               264                             264
# unique              189                             214
# top                   0                               0
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_excel('factbook.xlsx')
df['Electricity - production(kWh)'].hist()
plt.show()
# df.plot(kind='scatter'.x='col1',y='col2')
# plt.show()

# %%
df.shape
# Out:
# (264, 45)

# %%
import pandas as pd
df=pd.read_excel('factbook.xlsx')
missing_data_df=df.fillna(0)
new_df.to_csv(r'C:\users\phil_chordz\Desktop\project.csv', index=False, header=True)
